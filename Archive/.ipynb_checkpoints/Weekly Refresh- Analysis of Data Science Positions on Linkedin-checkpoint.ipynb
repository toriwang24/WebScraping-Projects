# %% [markdown]
# ## This notebook is a clone of "Analysis of Data Science Positions on LinkedIn"
#
# In this notebook, I try to do a weekly refresh of jobs that have been posted only in the last week.

# %%
import requests
from bs4 import BeautifulSoup
import random
import pandas as pd

# %% [markdown]
# ## The following cell collects linkedin job data and only adds jobs that have been posted in the past week to the dataframe

# %%
## Creating loop to go through all pages
job_list = []
for page_num in range(1,200):
    list_url = f"https://www.linkedin.com/jobs-guest/jobs/api/seeMoreJobPostings/search?keywords=Data%2BScientist&location=San%2BFrancisco%2BBay%2BArea&geoId=90000084&trk=public_jobs_jobs-search-bar_search-submit&start={page_num}" 
    # Getting response request from list 
    response = requests.get(list_url)

    list_data = response.text
    list_soup = BeautifulSoup(list_data, 'html.parser')
    page_jobs = list_soup.find_all("li")
    #10 jobs per page
    #print(len(page_jobs))
    
    ## Get job ID's from each page
    id_list = []

    for job in page_jobs:
        base_card_div = job.find("div", {"class": "base-card"})
        job_id = base_card_div.get("data-entity-urn").split(":")[3]
        id_list.append(job_id)
        
    # For every job with ID, get the information
    for job_id in id_list:
        job_url = f"https://www.linkedin.com/jobs-guest/jobs/api/jobPosting/{job_id}"
        job_response = requests.get(job_url)
        if(job_response.status_code == 200):
            #print(job_response.status_code)
            job_soup = BeautifulSoup(job_response.text, "html.parser")
            job_post = {}
            try:
                job_post["days_ago_posted"] = job_soup.find( "span", {"class": "posted-time-ago__text topcard__flavor--metadata"}).text.strip()
            except:
                job_post["days_ago_posted"] = None
            if(job_post["days_ago_posted"] != None and ("days" in job_post["days_ago_posted"] or "hours" in job_post["days_ago_posted"])): 
                try:
                    job_post["company_name"] = job_soup.find( "a", {"class": "topcard__org-name-link topcard__flavor--black-link"}).text.strip()
                except: 
                    job_post["company_name"] = None
                try:
                    job_post["job_title"] = job_soup.find( "h2", {"class": "top-card-layout__title font-sans text-lg papabear:text-xl font-bold leading-open text-color-text mb-0 topcard__title"}).text.strip()
                except: 
                    job_post["job_title"] = None
                try:
                    job_post["job_description"] = job_soup.find( "div", {"class":"show-more-less-html__markup show-more-less-html__markup--clamp-after-5 relative overflow-hidden" }).text.strip()
                except: 
                    job_post["job_description"] = None
                try:
                    job_post["num_applicants"] = job_soup.find( "figcaption", {"class": "num-applicants__caption"}).text.strip()
                except:
                    job_post["num_applicants"] = None
                job_list.append(job_post)

# %%
jobs_df = pd.DataFrame(job_list)
jobs_df
# Out:
#     days_ago_posted              company_name  \
# 0        2 days ago                   Netflix
# 1        4 days ago                    Notion
# 2        6 days ago                    Ikigai
# 3        5 days ago                  LinkedIn
# 4        2 days ago                   Netflix
# ..              ...                       ...
# 150      4 days ago                    Verily
# 151      5 days ago                 Bosch USA
# 152      4 days ago            Scion Staffing
# 153      4 days ago                    Verily
# 154      5 days ago  Foundation Model Startup
#
#                                          job_title  \
# 0    Machine Learning Engineer Intern, Summer 2025
# 1                          Data Scientist, Finance
# 2                                   AI/ML Engineer
# 3        Staff Data Scientist, Strategy & Insights
# 4    Machine Learning Engineer Intern, Summer 2025
# ..                                             ...
# 150               Data Scientist Evaluation Intern
# 151                  AI Research Scientist – GenAI
# 152                                 AI/ML Engineer
# 153               Data Scientist Evaluation Intern
# 154                                    AI Engineer
#
#                                        job_description       num_applicants
# 0    Netflix is one of the world's leading entertai...  Over 200 applicants
# 1    About UsWe're on a mission to make it possible...  Over 200 applicants
# 2    Company DescriptionThe Ikigai platform unlocks...  Over 200 applicants
# 3    LinkedIn is the world’s largest professional n...  Over 200 applicants
# 4    Netflix is one of the world's leading entertai...  Over 200 applicants
# ..                                                 ...                  ...
# 150  Who We AreVerily is a subsidiary of Alphabet t...  Over 200 applicants
# 151  Company DescriptionThe Bosch Research and Tech...                 None
# 152  Scion Technology Staffing has been engaged to ...                 None
# 153  Who We AreVerily is a subsidiary of Alphabet t...  Over 200 applicants
# 154  Our workWe are a well capitalized stealth VC-b...  Over 200 applicants
#
# [155 rows x 5 columns]

# %%
jobs_df.to_csv('data_01222025.csv', index=False)

# %% [markdown]
# ## From here on we will use the data_01222025.csv file that we exported the data to

# %%
import os
import pandas as pd
os.getcwd()
# Out:
# '/Users/toriwang/Documents/GitHub/WebScraping-Projects'

# %%
import sys
print(sys.executable)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/bin/python3.10

# %%
jobs_df = pd.read_csv('data_01222025.csv')

# %%
print(type(jobs_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#getting intern positions
jobs_df['Intern_position'] = (jobs_df['job_title'].str.contains('Intern')
                                       .map({True : 'yes', False : 'no'}))

# %%
jobs_df
# Out:
#     days_ago_posted              company_name  \
# 0        2 days ago                   Netflix
# 1        4 days ago                    Notion
# 2        6 days ago                    Ikigai
# 3        5 days ago                  LinkedIn
# 4        2 days ago                   Netflix
# ..              ...                       ...
# 150      4 days ago                    Verily
# 151      5 days ago                 Bosch USA
# 152      4 days ago            Scion Staffing
# 153      4 days ago                    Verily
# 154      5 days ago  Foundation Model Startup
#
#                                          job_title  \
# 0    Machine Learning Engineer Intern, Summer 2025
# 1                          Data Scientist, Finance
# 2                                   AI/ML Engineer
# 3        Staff Data Scientist, Strategy & Insights
# 4    Machine Learning Engineer Intern, Summer 2025
# ..                                             ...
# 150               Data Scientist Evaluation Intern
# 151                  AI Research Scientist – GenAI
# 152                                 AI/ML Engineer
# 153               Data Scientist Evaluation Intern
# 154                                    AI Engineer
#
#                                        job_description       num_applicants  \
# 0    Netflix is one of the world's leading entertai...  Over 200 applicants
# 1    About UsWe're on a mission to make it possible...  Over 200 applicants
# 2    Company DescriptionThe Ikigai platform unlocks...  Over 200 applicants
# 3    LinkedIn is the world’s largest professional n...  Over 200 applicants
# 4    Netflix is one of the world's leading entertai...  Over 200 applicants
# ..                                                 ...                  ...
# 150  Who We AreVerily is a subsidiary of Alphabet t...  Over 200 applicants
# 151  Company DescriptionThe Bosch Research and Tech...                  NaN
# 152  Scion Technology Staffing has been engaged to ...                  NaN
# 153  Who We AreVerily is a subsidiary of Alphabet t...  Over 200 applicants
# 154  Our workWe are a well capitalized stealth VC-b...  Over 200 applicants
#
#     Intern_position
# 0               yes
# 1                no
# 2                no
# 3                no
# 4               yes
# ..              ...
# 150             yes
# 151              no
# 152              no
# 153             yes
# 154              no
#
# [155 rows x 6 columns]

# %% [markdown]
# # Machine Learning Techniques

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk import ngrams
import nltk.collocations
from nltk import BigramCollocationFinder
from nltk.probability import FreqDist

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
stop_words = set(stopwords.words("english"))
stop_words.add(':')
stop_words.add(',')
stop_words.add('.')
stop_words.add(', ')
stop_words.add('. ')
stop_words.add('*')
stop_words.add("'")
stop_words.add("'s")
stop_words.add('e.g')
stop_words.add('employees')
stop_words.add('applicants')
stop_words.add(')')
stop_words.add('(')
stop_words.add('eligible')
stop_words.add('participate')

# %%
def get_n_grams(word_list, n, top_n):
    '''
        Function to return ngrams
        word_list: pass lowercase word list (filtered for stop words)
        n: the number of words in each phrase (gram)
        top_n: top n number of matches 
    '''
    grams = list(ngrams(word_list, n))
    freq_dist = FreqDist(grams)
    
    topn = freq_dist.most_common(top_n)
    return(topn)

# %%
def return_n_grams():
    bigram_list = []
    # trigram_list = []
    
    #Create a dictionary of the most common bigrams
    bigram_dict = {}
    # trigram_dict = {}
    
    #for every job in job_list dataframe
    for i in range(len(jobs_df)): # change to len(jobs_df)
        # print(jobs_df['job_description'][i], '\n')
        # Grab the job description
        text = jobs_df['job_description'][i]
    
        #Tokenize and filter unnecessary words, and put relevant words i
        tokens = word_tokenize(text)
        filtered_list = []
        for word in tokens:
            if word.casefold() not in stop_words:
                filtered_list.append(word.lower())  
        
        # For bigrams
        # add bigrams
        top8 = get_n_grams(filtered_list, 2, 8)
        bigram_list.append(top8)
        for tup in top8:
            if tup[0] not in bigram_dict:
                bigram_dict[tup[0]] = tup[1]
            else:
                bigram_dict[tup[0]] += tup[1]
    return (sorted(bigram_dict.items(), key=lambda item: item[1],  reverse=True))

# %%
## In this cell I'm going to add the list of common tokens to the dataframe

bigram_list = []
trigram_list = []

#Create a dictionary of the most common bigrams
bigram_dict = {}
trigram_dict = {}

#for every job in job_list dataframe
for i in range(len(jobs_df)): # change to len(jobs_df)
    # print(jobs_df['job_description'][i], '\n')
    # Grab the job description
    text = jobs_df['job_description'][i]

    #Tokenize and filter unnecessary words, and put relevant words i
    tokens = word_tokenize(text)
    filtered_list = []
    for word in tokens:
        if word.casefold() not in stop_words:
            filtered_list.append(word.lower())  
    
    # For bigrams
    # add bigrams
    top8 = get_n_grams(filtered_list, 2, 8)
    bigram_list.append(top8)
    for tup in top8:
        if tup[0] not in bigram_dict:
            bigram_dict[tup[0]] = tup[1]
        else:
            bigram_dict[tup[0]] += tup[1]

    # add trigrams
    top5 = get_n_grams(filtered_list, 3, 2)
    bigram_list.append(top5)
    for tup in top5:
        if tup[0] not in bigram_dict:
            trigram_dict[tup[0]] = tup[1]
        else:
            trigram_dict[tup[0]] += tup[1]

# %%
sorted_bigram = (sorted(bigram_dict.items(), key=lambda item: item[1],  reverse=True))
sorted_trigram = (sorted(trigram_dict.items(), key=lambda item: item[1],  reverse=True))

# %%
from pprint import pprint
pprint(sorted_bigram[:100])
# Out:
# [(('machine', 'learning'), 223),
#  (('data', 'science'), 93),
#  (('equal', 'opportunity'), 53),
#  (('deep', 'learning'), 40),
#  (('model', 'training'), 36),
#  (('cross-functional', 'teams'), 35),
#  (('usa', ';'), 35),
#  (('&', 'ai'), 30),
#  (('years', 'experience'), 28),
#  (('intercom', '’'), 27),
#  (('fp', '&'), 27),
#  (('tecton', '’'), 24),
#  (('use', 'cases'), 24),
#  (('least', '18+'), 24),
#  (('18+', 'years'), 24),
#  (('enrolled', 'full-time'), 24),
#  (('full-time', 'student'), 24),
#  (('generative', 'ai'), 24),
#  (('ikigai', 'labs'), 21),
#  (('linkedin', 'committed'), 21),
#  (('opportunity', 'employer'), 21),
#  (('google', '’'), 21),
#  (('insight', 'cloud'), 21),
#  (('analytics', 'apps'), 21),
#  (('business', 'metrics'), 20),
#  (('new', 'york'), 18),
#  (('’', 'genai'), 18),
#  (('genai', 'use'), 18),
#  (('learning', 'ai'), 18),
#  (('founding', 'team'), 18),
#  (('deployment', 'monitoring'), 18),
#  (('us', '!'), 18),
#  (('eds', '&'), 18),
#  (('voice', 'ai'), 18),
#  (('ai', 'technology'), 18),
#  (('ai', 'models'), 18),
#  (('evaluation', 'strategies'), 18),
#  (('responsible', 'ai'), 18),
#  (('evaluation', 'frameworks'), 18),
#  (('ai', 'customer'), 18),
#  (('customer', 'service'), 18),
#  (('finance', 'product'), 18),
#  (('product', 'gtm'), 18),
#  (('data', 'engineering'), 18),
#  (("'re", 'looking'), 18),
#  (('using', 'aws'), 18),
#  (('aws', 'bedrock'), 18),
#  (('artificial', 'intelligence'), 16),
#  (('ai', 'products'), 16),
#  (('ai', 'data'), 16),
#  (('data', 'scientist'), 16),
#  (('year', '’'), 15),
#  (('ai', 'application'), 15),
#  (('skills', 'experience'), 15),
#  (('nlp', 'deep'), 15),
#  (('business', 'users'), 14),
#  (('ml', 'solutions'), 14),
#  (('kubernetes', 'helm'), 14),
#  (('ml', 'deep'), 14),
#  (('modeling', 'platform'), 14),
#  (('backgrounds', 'experiences'), 14),
#  (('economic', 'opportunity'), 14),
#  (('opportunity', 'every'), 14),
#  (('every', 'member'), 14),
#  (('ca', 'usa'), 14),
#  (('experience', 'using'), 14),
#  (('using', 'analytics'), 14),
#  (('analytics', 'solve'), 14),
#  (('solve', 'product'), 14),
#  (('analytics', 'developers'), 14),
#  (('developers', 'consumers'), 14),
#  (('-', 'driving'), 14),
#  (('driving', 'business'), 14),
#  (('structured', 'unstructured'), 14),
#  (('data', 'visualization'), 14),
#  (('strategy', 'data-centric'), 14),
#  (('global', 'data'), 14),
#  (('ai', 'applications'), 12),
#  (('offices', 'san'), 12),
#  (('tools', 'e.g.'), 12),
#  (('student', 'accredited'), 12),
#  (('accredited', 'institution'), 12),
#  (('”', 'team'), 12),
#  (('center', 'excellence'), 12),
#  (('team', 'department'), 12),
#  (('across', 'company'), 12),
#  (('future', 'drive-thru'), 12),
#  (('drive-thru', 'ordering'), 12),
#  (('customer', 'experience'), 12),
#  (('quick-service', 'restaurant'), 12),
#  (('data', 'pipelines'), 12),
#  (('automation', 'tools'), 12),
#  (('training', 'deployment'), 12),
#  (('job', 'description'), 12),
#  (('difference', 'database'), 12),
#  (('application', 'hosted'), 12),
#  (('technology', 'data'), 12),
#  (('science', 'healthcare'), 12),
#  (('13', 'week'), 12),
#  (('performance', 'safety'), 12)]

# %% [markdown]
# # Are there any jobs without over 200 applicants lol

# %%
jobs_df.loc[jobs_df['num_applicants'] != "Over 200 applicants"]
# Out:
#     days_ago_posted     company_name  \
# 35       6 days ago             seer
# 40       6 days ago             seer
# 43       6 days ago             seer
# 46       6 days ago             seer
# 48       6 days ago             seer
# 60       4 days ago   Scion Staffing
# 66       6 days ago             seer
# 67       6 days ago             seer
# 73       4 days ago  Diamond Foundry
# 80       5 days ago           Google
# 85       5 days ago           Google
# 87       5 days ago           Google
# 88       5 days ago           Google
# 89       5 days ago           Google
# 90       5 days ago           Google
# 91       5 days ago           Google
# 110      4 days ago  Diamond Foundry
# 112      4 days ago  Diamond Foundry
# 145      5 days ago        Bosch USA
# 147      5 days ago        Bosch USA
# 151      5 days ago        Bosch USA
# 152      4 days ago   Scion Staffing
#
#                                              job_title  \
# 35                                    AI/ML Researcher
# 40                                    AI/ML Researcher
# 43                                    AI/ML Researcher
# 46                                    AI/ML Researcher
# 48                                    AI/ML Researcher
# 60                                      AI/ML Engineer
# 66                                    AI/ML Researcher
# 67                                    AI/ML Researcher
# 73                                      Data Scientist
# 80   Data Scientist, Research, Power Forecasting an...
# 85   Data Scientist, Research, Power Forecasting an...
# 87   Data Scientist, Research, Power Forecasting an...
# 88   Data Scientist, Research, Power Forecasting an...
# 89   Data Scientist, Research, Power Forecasting an...
# 90   Data Scientist, Research, Power Forecasting an...
# 91   Data Scientist, Research, Power Forecasting an...
# 110                                     Data Scientist
# 112                                     Data Scientist
# 145                      AI Research Scientist – GenAI
# 147                      AI Research Scientist – GenAI
# 151                      AI Research Scientist – GenAI
# 152                                     AI/ML Engineer
#
#                                        job_description num_applicants  \
# 35   We are currently working with a Biotech Unicor...            NaN
# 40   We are currently working with a Biotech Unicor...            NaN
# 43   We are currently working with a Biotech Unicor...            NaN
# 46   We are currently working with a Biotech Unicor...            NaN
# 48   We are currently working with a Biotech Unicor...            NaN
# 60   Scion Technology Staffing has been engaged to ...            NaN
# 66   We are currently working with a Biotech Unicor...            NaN
# 67   We are currently working with a Biotech Unicor...            NaN
# 73   Diamond Foundry Inc. is solving the thermal li...            NaN
# 80   Note: By applying to this position you will ha...            NaN
# 85   Note: By applying to this position you will ha...            NaN
# 87   Note: By applying to this position you will ha...            NaN
# 88   Note: By applying to this position you will ha...            NaN
# 89   Note: By applying to this position you will ha...            NaN
# 90   Note: By applying to this position you will ha...            NaN
# 91   Note: By applying to this position you will ha...            NaN
# 110  Diamond Foundry Inc. is solving the thermal li...            NaN
# 112  Diamond Foundry Inc. is solving the thermal li...            NaN
# 145  Company DescriptionThe Bosch Research and Tech...            NaN
# 147  Company DescriptionThe Bosch Research and Tech...            NaN
# 151  Company DescriptionThe Bosch Research and Tech...            NaN
# 152  Scion Technology Staffing has been engaged to ...            NaN
#
#     Intern_position
# 35               no
# 40               no
# 43               no
# 46               no
# 48               no
# 60               no
# 66               no
# 67               no
# 73               no
# 80               no
# 85               no
# 87               no
# 88               no
# 89               no
# 90               no
# 91               no
# 110              no
# 112              no
# 145              no
# 147              no
# 151              no
# 152              no

# %%
jobs_df[jobs_df["Intern_position"].str.contains("no")]
# Out:
#     days_ago_posted              company_name  \
# 1        4 days ago                    Notion
# 2        6 days ago                    Ikigai
# 3        5 days ago                  LinkedIn
# 5        4 days ago                    Notion
# 6        6 days ago                    Ikigai
# ..              ...                       ...
# 148      6 days ago                    Saicon
# 149      5 days ago  Foundation Model Startup
# 151      5 days ago                 Bosch USA
# 152      4 days ago            Scion Staffing
# 154      5 days ago  Foundation Model Startup
#
#                                              job_title  \
# 1                              Data Scientist, Finance
# 2                                       AI/ML Engineer
# 3            Staff Data Scientist, Strategy & Insights
# 5                              Data Scientist, Finance
# 6                                       AI/ML Engineer
# ..                                                 ...
# 148  Machine Learning Artificial Intelligence Engineer
# 149                                        AI Engineer
# 151                      AI Research Scientist – GenAI
# 152                                     AI/ML Engineer
# 154                                        AI Engineer
#
#                                        job_description       num_applicants  \
# 1    About UsWe're on a mission to make it possible...  Over 200 applicants
# 2    Company DescriptionThe Ikigai platform unlocks...  Over 200 applicants
# 3    LinkedIn is the world’s largest professional n...  Over 200 applicants
# 5    About UsWe're on a mission to make it possible...  Over 200 applicants
# 6    Company DescriptionThe Ikigai platform unlocks...  Over 200 applicants
# ..                                                 ...                  ...
# 148  Need : Machine Learning Artificial Intelligenc...  Over 200 applicants
# 149  Our workWe are a well capitalized stealth VC-b...  Over 200 applicants
# 151  Company DescriptionThe Bosch Research and Tech...                  NaN
# 152  Scion Technology Staffing has been engaged to ...                  NaN
# 154  Our workWe are a well capitalized stealth VC-b...  Over 200 applicants
#
#     Intern_position
# 1                no
# 2                no
# 3                no
# 5                no
# 6                no
# ..              ...
# 148              no
# 149              no
# 151              no
# 152              no
# 154              no
#
# [129 rows x 6 columns]

# %% [markdown]
# # Weekly Refresh 3/17/2024

# %%
def scrape_jobs():
    job_list = []
    for page_num in range(1,200):
        list_url = f"https://www.linkedin.com/jobs-guest/jobs/api/seeMoreJobPostings/search?keywords=Data%2BScientist&location=San%2BFrancisco%2BBay%2BArea&geoId=90000084&trk=public_jobs_jobs-search-bar_search-submit&start={page_num}" 
        # Getting response request from list 
        response = requests.get(list_url)
    
        list_data = response.text
        list_soup = BeautifulSoup(list_data, 'html.parser')
        page_jobs = list_soup.find_all("li")
        #10 jobs per page
        #print(len(page_jobs))
        
        ## Get job ID's from each page
        id_list = []
    
        for job in page_jobs:
            base_card_div = job.find("div", {"class": "base-card"})
            job_id = base_card_div.get("data-entity-urn").split(":")[3]
            id_list.append(job_id)
            
        # For every job with ID, get the information
        for job_id in id_list:
            job_url = f"https://www.linkedin.com/jobs-guest/jobs/api/jobPosting/{job_id}"
            job_response = requests.get(job_url)
            if(job_response.status_code == 200):
                #print(job_response.status_code)
                job_soup = BeautifulSoup(job_response.text, "html.parser")
                job_post = {}
                try:
                    job_post["days_ago_posted"] = job_soup.find( "span", {"class": "posted-time-ago__text topcard__flavor--metadata"}).text.strip()
                except:
                    job_post["days_ago_posted"] = None
                if(job_post["days_ago_posted"] != None and ("days" in job_post["days_ago_posted"] or "hours" in job_post["days_ago_posted"])): 
                    try:
                        job_post["company_name"] = job_soup.find( "a", {"class": "topcard__org-name-link topcard__flavor--black-link"}).text.strip()
                    except: 
                        job_post["company_name"] = None
                    try:
                        job_post["job_title"] = job_soup.find( "h2", {"class": "top-card-layout__title font-sans text-lg papabear:text-xl font-bold leading-open text-color-text mb-0 topcard__title"}).text.strip()
                    except: 
                        job_post["job_title"] = None
                    try:
                        job_post["job_description"] = job_soup.find( "div", {"class":"show-more-less-html__markup show-more-less-html__markup--clamp-after-5 relative overflow-hidden" }).text.strip()
                    except: 
                        job_post["job_description"] = None
                    try:
                        job_post["num_applicants"] = job_soup.find( "figcaption", {"class": "num-applicants__caption"}).text.strip()
                    except:
                        job_post["num_applicants"] = None
                    job_list.append(job_post)
    return pd.DataFrame(job_list)

# %%
jobs_df = scrape_jobs()

# %%
jobs_df.to_csv('data_20250317.csv', index=False)

# %%
import os
import pandas as pd
os.getcwd()
# Out:
# '/Users/toriwang/Documents/GitHub/WebScraping-Projects'

# %%
jobs_df = pd.read_csv('data_01222025.csv')

# %%
jobs_df
# Out:
#     days_ago_posted              company_name  \
# 0        2 days ago                   Netflix
# 1        4 days ago                    Notion
# 2        6 days ago                    Ikigai
# 3        5 days ago                  LinkedIn
# 4        2 days ago                   Netflix
# ..              ...                       ...
# 150      4 days ago                    Verily
# 151      5 days ago                 Bosch USA
# 152      4 days ago            Scion Staffing
# 153      4 days ago                    Verily
# 154      5 days ago  Foundation Model Startup
#
#                                          job_title  \
# 0    Machine Learning Engineer Intern, Summer 2025
# 1                          Data Scientist, Finance
# 2                                   AI/ML Engineer
# 3        Staff Data Scientist, Strategy & Insights
# 4    Machine Learning Engineer Intern, Summer 2025
# ..                                             ...
# 150               Data Scientist Evaluation Intern
# 151                  AI Research Scientist – GenAI
# 152                                 AI/ML Engineer
# 153               Data Scientist Evaluation Intern
# 154                                    AI Engineer
#
#                                        job_description       num_applicants
# 0    Netflix is one of the world's leading entertai...  Over 200 applicants
# 1    About UsWe're on a mission to make it possible...  Over 200 applicants
# 2    Company DescriptionThe Ikigai platform unlocks...  Over 200 applicants
# 3    LinkedIn is the world’s largest professional n...  Over 200 applicants
# 4    Netflix is one of the world's leading entertai...  Over 200 applicants
# ..                                                 ...                  ...
# 150  Who We AreVerily is a subsidiary of Alphabet t...  Over 200 applicants
# 151  Company DescriptionThe Bosch Research and Tech...                  NaN
# 152  Scion Technology Staffing has been engaged to ...                  NaN
# 153  Who We AreVerily is a subsidiary of Alphabet t...  Over 200 applicants
# 154  Our workWe are a well capitalized stealth VC-b...  Over 200 applicants
#
# [155 rows x 5 columns]
